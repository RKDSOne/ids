# %% [markdown]
# # Platform For Trying Python Methods
# Here's the platform for trying some python tools and see if they work.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import *
# %matplotlib inline

# %% [markdown]
# ## SMOTE Algorithm
# Testing the SMOTE algorithm online, I'm doubting if it works.
#
# ### Data generation
# We generate 2 imbalanced classes of data with,
# * Minor (40 samples): $x\sim N(0,1)$
# * Major (200 samples): $y\sim N(10,25)$

# %%
x=np.random.randn(40)
y=np.random.randn(40)
d1=zip(x,y)
x=np.random.randn(200)*5+10
y=np.random.randn(200)*5+10
d2=zip(x,y)
plt.plot(zip(*d1)[0], zip(*d1)[1], 'x')
plt.plot(zip(*d2)[0], zip(*d2)[1], 'o')
plt.gcf().set_size_inches(12,7)
plt.show()
